# %% [markdown]
# # **SpaceX Launch Records Dashboard**
# #### by Daniel Eduardo López (2022-07-22)

# %% [markdown]
# An overall view of the Dashboard is the following:

# %% [markdown]
# ![1. Overall view.png](data:image/png;base64,...)

# %% [markdown]
# ### **Structure of the Dashboard**

# %% [markdown]
# The Dashboard comprises:

# %% [markdown]
# 1. A **Header**.

# %% [markdown]
# ![2. Header.png](data:image/png;base64,...)

# %% [markdown]
# 2. A **Dropdown** for the Launch Site Selection.

# %% [markdown]
# ![2. Dropdown.png](data:image/png;base64,...)

# %% [markdown]
# 2. A **Pie chart** with the Total Success Launches by Site. If the option "All Sites" is selected in the dropdown above, then the Pie Chart will render the Total Success Launches by Site. On the other hand, if a specific launch site is selected in the dropdown above, then the Pie Chart will render Total Success Launches at that site only (0 = unsuccessfull, 1 = successfull).

# %% [markdown]
# ![4. Pie Chart 1.png](data:image/png;base64,...)

# %% [markdown]
# ![5. Pie Chart 2.png](data:image/png;base64,...)

# %% [markdown]
# 3. A **Range Slider**  to select Payload.

# %% [markdown]
# ![6. Slider.png](data:image/png;base64,...)

# %% [markdown]
# 4. A **Scatter Plot** in which the correlation among payload and mission outcomes for selected site(s) is observed. This plot is interactive according to the selected values in the Launching Site Dropdown and the Payload Range Slider above.

# %% [markdown]
# ![7. Scatter Plot.png](data:image/png;base64,...)

# %% [markdown]
# ![8. Scatter Plot 2.png](data:image/png;base64,...)

# %% [markdown]
# ### **Insights**

# %% [markdown]
# 1. Which site has the largest successful launches? **KSC LC-39A**.

# %% [markdown]
# ![9. Answer1.png](data:image/png;base64,...)

# %% [markdown]
# 2. Which site has the highest launch success rate? **The KSC LC-39A with 76.9%**.

# %% [markdown]
# ![10. Answer2.png](data:image/png;base64,...)

# %% [markdown]
# 3. Which payload range(s) has the highest launch success rate? **From 1952 kg to 5300 kg**.

# %% [markdown]
# ![11. Answer3 modified.png](data:image/png;base64,...)

# %% [markdown]
# 4. Which payload range(s) has the lowest launch success rate? **Below 1952 kg and above 5300 kg**.

# %% [markdown]
# ![12. Answer4.png](data:image/png;base64,...)

# %% [markdown]
# 5. Which F9 Booster version (v1.0, v1.1, FT, B4, B5, etc.) has the highest launch success rate? **The FT and the B5 Booster versions**.

# %% [markdown]
# ![13. Answer5.png](data:image/png;base64,...)

# %%
# Thanks!
